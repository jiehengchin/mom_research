# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from binance_data_loader import BinanceDataLoader
from tqdm import tqdm

# %%
data_loader = BinanceDataLoader(
    data_directory=r"C:\Users\USER\Documents\Binance_related\dailytickerdata2020",
    min_records=30,
    min_volume=1e5,
    start_date="2021-01-01",
    end_date=None
)
# Out:
# Loading Binance data from C:\Users\USER\Documents\Binance_related\dailytickerdata2020...
# Found 551 USDT trading pairs
# ✓ BTCUSDT loaded successfully with 1732 records, avg volume: 359,624
# Loaded 517 cryptocurrencies
# Filtered 32 cryptocurrencies (insufficient data/volume)
# Precomputing returns matrix (FAST numpy version)...
# Building returns matrix for 516 tickers over 1732 dates...
# Precomputed returns matrix shape: (1732, 516)
# Date range: 2021-01-01 00:00:00 to 2025-09-28 00:00:00

# %%
price = data_loader.get_price_matrix()
price
# Out:
#             1000000BOBUSDT  1000000MOGUSDT  1000BONKUSDT  1000CATUSDT  \
# 2021-01-01             NaN             NaN           NaN          NaN
# 2021-01-02             NaN             NaN           NaN          NaN
# 2021-01-03             NaN             NaN           NaN          NaN
# 2021-01-04             NaN             NaN           NaN          NaN
# 2021-01-05             NaN             NaN           NaN          NaN
# ...                    ...             ...           ...          ...
# 2025-09-24         0.04602          0.6957      0.020222     0.007291
# 2025-09-25         0.03969          0.6251      0.018832     0.006682
# 2025-09-26         0.04131          0.6556      0.019647     0.006950
# 2025-09-27         0.04037          0.6443      0.019091     0.007163
# 2025-09-28         0.03967          0.6524      0.018880     0.007039
#
#             1000CHEEMSUSDT  1000FLOKIUSDT  1000LUNCUSDT  1000PEPEUSDT  \
# 2021-01-01             NaN            NaN           NaN           NaN
# 2021-01-02             NaN            NaN           NaN           NaN
# 2021-01-03             NaN            NaN           NaN           NaN
# 2021-01-04             NaN            NaN           NaN           NaN
# 2021-01-05             NaN            NaN           NaN           NaN
# ...                    ...            ...           ...           ...
# 2025-09-24        0.001177        0.08524       0.05534      0.009634
# 2025-09-25        0.001087        0.07970       0.05277      0.009068
# 2025-09-26        0.001110        0.08311       0.05418      0.009374
# 2025-09-27        0.001106        0.08146       0.05396      0.009237
# 2025-09-28        0.001098        0.08073       0.05384      0.009173
#
#             1000RATSUSDT  1000SATSUSDT  ...  ZENUSDT  ZEREBROUSDT  ZETAUSDT  \
# 2021-01-01           NaN           NaN  ...   11.802          NaN       NaN
# 2021-01-02           NaN           NaN  ...   11.784          NaN       NaN
# 2021-01-03           NaN           NaN  ...   13.599          NaN       NaN
# 2021-01-04           NaN           NaN  ...   13.497          NaN       NaN
# 2021-01-05           NaN           NaN  ...   14.447          NaN       NaN
# ...                  ...           ...  ...      ...          ...       ...
# 2025-09-24       0.02697      0.000037  ...    6.896      0.01758    0.1739
# 2025-09-25       0.02753      0.000040  ...    6.246      0.01732    0.1638
# 2025-09-26       0.02709      0.000051  ...    6.405      0.01759    0.1682
# 2025-09-27       0.02960      0.000043  ...    6.379      0.01759    0.1660
# 2025-09-28       0.02684      0.000040  ...    6.339      0.01748    0.1634
#
#             ZILUSDT  ZKJUSDT   ZKUSDT  ZORAUSDT  ZRCUSDT  ZROUSDT  ZRXUSDT
# 2021-01-01  0.07883      NaN      NaN       NaN      NaN      NaN   0.3747
# 2021-01-02  0.07226      NaN      NaN       NaN      NaN      NaN   0.3611
# 2021-01-03  0.06800      NaN      NaN       NaN      NaN      NaN   0.3942
# 2021-01-04  0.07005      NaN      NaN       NaN      NaN      NaN   0.3961
# 2021-01-05  0.07043      NaN      NaN       NaN      NaN      NaN   0.4464
# ...             ...      ...      ...       ...      ...      ...      ...
# 2025-09-24  0.01083   0.1428  0.05053   0.06199  0.02197   2.1584   0.2414
# 2025-09-25  0.01017   0.1288  0.04684   0.05940  0.02066   2.1503   0.2271
# 2025-09-26  0.01042   0.1320  0.04989   0.05722  0.02135   2.3594   0.2385
# 2025-09-27  0.01040   0.1289  0.05003   0.05671  0.02113   2.2863   0.2358
# 2025-09-28  0.01031   0.1301  0.04958   0.05647  0.02111   2.2857   0.2344
#
# [1732 rows x 516 columns]

# %%
n =14
rets = price.shift(1).pct_change(n)
equity = [1.0]
rets
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_24720\2361134782.py:2: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   rets = price.shift(1).pct_change(n)
#             1000000BOBUSDT  1000000MOGUSDT  1000BONKUSDT  1000CATUSDT  \
# 2021-01-01             NaN             NaN           NaN          NaN
# 2021-01-02             NaN             NaN           NaN          NaN
# 2021-01-03             NaN             NaN           NaN          NaN
# 2021-01-04             NaN             NaN           NaN          NaN
# 2021-01-05             NaN             NaN           NaN          NaN
# ...                    ...             ...           ...          ...
# 2025-09-24       -0.146432       -0.232753     -0.106764    -0.046210
# 2025-09-25       -0.120245       -0.230591     -0.128137    -0.069194
# 2025-09-26       -0.284349       -0.345308     -0.229775    -0.152353
# 2025-09-27       -0.271685       -0.354089     -0.234513    -0.164965
# 2025-09-28       -0.299983       -0.385855     -0.267927    -0.153009
#
#             1000CHEEMSUSDT  1000FLOKIUSDT  1000LUNCUSDT  1000PEPEUSDT  \
# 2021-01-01             NaN            NaN           NaN           NaN
# 2021-01-02             NaN            NaN           NaN           NaN
# 2021-01-03             NaN            NaN           NaN           NaN
# 2021-01-04             NaN            NaN           NaN           NaN
# 2021-01-05             NaN            NaN           NaN           NaN
# ...                    ...            ...           ...           ...
# 2025-09-24        0.002214      -0.116504     -0.075321     -0.072153
# 2025-09-25       -0.011088      -0.124666     -0.088153     -0.084731
# 2025-09-26       -0.100124      -0.203319     -0.132786     -0.151805
# 2025-09-27       -0.101255      -0.206208     -0.117014     -0.187742
# 2025-09-28       -0.127181      -0.237694     -0.129397     -0.224659
#
#             1000RATSUSDT  1000SATSUSDT  ...   ZENUSDT  ZEREBROUSDT  ZETAUSDT  \
# 2021-01-01           NaN           NaN  ...       NaN          NaN       NaN
# 2021-01-02           NaN           NaN  ...       NaN          NaN       NaN
# 2021-01-03           NaN           NaN  ...       NaN          NaN       NaN
# 2021-01-04           NaN           NaN  ...       NaN          NaN       NaN
# 2021-01-05           NaN           NaN  ...       NaN          NaN       NaN
# ...                  ...           ...  ...       ...          ...       ...
# 2025-09-24      0.226396     -0.139949  ... -0.082975    -0.138836 -0.084267
# 2025-09-25      0.288581     -0.115385  ... -0.078937    -0.195055 -0.080381
# 2025-09-26      0.275718     -0.012255  ... -0.173700    -0.196660 -0.136076
# 2025-09-27      0.215889      0.191038  ... -0.170981    -0.245064 -0.140960
# 2025-09-28      0.341795      0.009368  ... -0.193960    -0.283503 -0.158642
#
#              ZILUSDT   ZKJUSDT    ZKUSDT  ZORAUSDT   ZRCUSDT   ZROUSDT  \
# 2021-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-09-24 -0.098910 -0.203535 -0.174608 -0.109638 -0.154171  0.044255
# 2025-09-25 -0.079082 -0.188175 -0.171368 -0.043954 -0.172193  0.070423
# 2025-09-26 -0.143939 -0.271081 -0.235515 -0.055344 -0.229679  0.058375
# 2025-09-27 -0.138131 -0.259675 -0.206458 -0.125210 -0.225608  0.162839
# 2025-09-28 -0.153784 -0.306989 -0.203978 -0.136308 -0.231077  0.098971
#
#              ZRXUSDT
# 2021-01-01       NaN
# 2021-01-02       NaN
# 2021-01-03       NaN
# 2021-01-04       NaN
# 2021-01-05       NaN
# ...              ...
# 2025-09-24 -0.143320
# 2025-09-25 -0.136624
# 2025-09-26 -0.184853
# 2025-09-27 -0.139610
# 2025-09-28 -0.172051
#
# [1732 rows x 516 columns]

# %%
# Get volume data for universe selection with 20-day rolling average
volume_data = {}
for ticker in data_loader.get_universe():
    ticker_data = data_loader._crypto_universe[ticker]['data']
    volume_data[ticker] = ticker_data['volume'].reindex(price.index)

volume_matrix = pd.DataFrame(volume_data, index=price.index)

# Calculate 20-day rolling average volume
rolling_volume_matrix = volume_matrix.rolling(window=20, min_periods=10).mean()

# Calculate rolling volatility for weighting (using 30-day window)
vol_window = 30
volatility = price.pct_change().rolling(vol_window).std()

# Calculate BTC 90-day total return for market filter
btc_90d_return = price["BTCUSDT"].pct_change(90)

# Calculate rolling beta with BTC as benchmark (using 30-day window)
beta_window = 30
btc_returns = price["BTCUSDT"].pct_change()
portfolio_betas = {}

k = 10  # Number of coins to go long/short
n_universe = 50  # Top N volume universe to select from each day

# Track current positions and last rebalance date
current_long_weights = pd.Series(dtype=float)
current_short_weights = pd.Series(dtype=float)
last_rebalance_date = None

# Main backtest loop - using volatility-based position sizing
for i in range(n, len(price)-1):
    current_date = price.index[i]

    # BTC Market Filter: Skip trading if BTC 90-day return is negative
    if not pd.isna(btc_90d_return.iloc[i]) and btc_90d_return.iloc[i] < 0:
        equity.append(equity[-1])  # Hold cash during crypto bear markets
        continue

    # Get 20-day rolling average volume for current date
    current_volumes = rolling_volume_matrix.iloc[i].dropna()

    # Skip if no volume data available
    if len(current_volumes) == 0:
        equity.append(equity[-1])
        continue

    # Select top N_universe by 20-day rolling volume for this day
    top_volume_tickers = current_volumes.nlargest(n_universe).index

    # Get momentum returns for the volume-filtered universe (score)
    row = rets.iloc[i]
    filtered_returns = row[top_volume_tickers].dropna()

    # Skip if no valid returns in the volume universe
    if len(filtered_returns) == 0:
        equity.append(equity[-1])
        continue

    # Calculate portfolio beta with BTC if we have current positions
    should_rebalance = True
    if len(current_long_weights) > 0 or len(current_short_weights) > 0:
        # Calculate portfolio returns for beta calculation
        start_beta_idx = max(0, i - beta_window + 1)
        
        portfolio_returns = []
        for j in range(start_beta_idx, i + 1):
            if j == 0:
                portfolio_returns.append(0)
                continue
                
            portfolio_return = 0
            
            # Calculate long portfolio return
            for coin, weight in current_long_weights.items():
                if coin in price.columns:
                    p_prev = price[coin].iloc[j-1]
                    p_curr = price[coin].iloc[j]
                    if np.isfinite(p_prev) and p_prev != 0 and np.isfinite(p_curr):
                        coin_return = (p_curr - p_prev) / p_prev
                        portfolio_return += weight * coin_return
            
            # Calculate short portfolio return
            for coin, weight in current_short_weights.items():
                if coin in price.columns:
                    p_prev = price[coin].iloc[j-1]
                    p_curr = price[coin].iloc[j]
                    if np.isfinite(p_prev) and p_prev != 0 and np.isfinite(p_curr):
                        coin_return = (p_curr - p_prev) / p_prev
                        portfolio_return += weight * coin_return  # Short positions have negative weight
            
            portfolio_returns.append(portfolio_return)
        
        portfolio_returns = pd.Series(portfolio_returns, index=price.index[start_beta_idx:i+1])
        btc_returns_subset = btc_returns.iloc[start_beta_idx:i+1]
        
        # Calculate beta if we have enough data
        if len(portfolio_returns) >= 10:
            valid_data = pd.DataFrame({'portfolio': portfolio_returns, 'btc': btc_returns_subset}).dropna()
            if len(valid_data) >= 10:
                portfolio_beta = np.cov(valid_data['portfolio'], valid_data['btc'])[0,1] / np.var(valid_data['btc'])
                
                # Only rebalance if beta >= 0.1
                should_rebalance = abs(portfolio_beta) >= 0.1

    # If not rebalancing, calculate return with current positions
    if not should_rebalance:
        portfolio_return = 0
        
        # Calculate long return
        for coin, weight in current_long_weights.items():
            if coin in price.columns:
                p0 = price[coin].iloc[i]
                p1 = price[coin].iloc[i+1]
                if np.isfinite(p0) and p0 != 0 and np.isfinite(p1):
                    coin_return = (p1 - p0) / p0
                    portfolio_return += weight * coin_return
        
        # Calculate short return
        for coin, weight in current_short_weights.items():
            if coin in price.columns:
                p0 = price[coin].iloc[i]
                p1 = price[coin].iloc[i+1]
                if np.isfinite(p0) and p0 != 0 and np.isfinite(p1):
                    coin_return = (p1 - p0) / p0
                    portfolio_return += weight * coin_return  # Short weights are negative
        
        # Apply fees only if we had positions
        if len(current_long_weights) > 0 or len(current_short_weights) > 0:
            portfolio_return -= 0.0005  # 5bps fees
        
        equity.append(equity[-1] * (1 + portfolio_return))
        continue

    # Rebalancing logic - select new positions
    long_coins = filtered_returns.nlargest(k).index   # top k momentum
    short_coins = filtered_returns.nsmallest(k).index # bottom k momentum

    # Get volatilities for selected coins
    long_vols = volatility.iloc[i][long_coins].dropna()
    short_vols = volatility.iloc[i][short_coins].dropna()

    # Skip if we don't have volatility data for any coins
    if len(long_vols) == 0 or len(short_vols) == 0:
        equity.append(equity[-1])
        continue

    # Calculate inverse volatility weights
    long_inv_vol = 1.0 / long_vols
    short_inv_vol = 1.0 / short_vols

    # Remove infinite values
    long_inv_vol = long_inv_vol.replace([np.inf, -np.inf], np.nan).dropna()
    short_inv_vol = short_inv_vol.replace([np.inf, -np.inf], np.nan).dropna()

    if len(long_inv_vol) == 0 or len(short_inv_vol) == 0:
        equity.append(equity[-1])
        continue

    # Normalize weights: (1/vol) / sum(same_side_1/vol) * 0.5
    long_weights = (long_inv_vol / long_inv_vol.sum()) * 0.5
    short_weights = (short_inv_vol / short_inv_vol.sum()) * -0.5  # Negative for short positions

    # Update current positions
    current_long_weights = long_weights
    current_short_weights = short_weights
    last_rebalance_date = current_date

    # Calculate weighted returns for the next day
    long_return = 0
    short_return = 0

    for coin in long_weights.index:
        p0 = price[coin].iloc[i]
        p1 = price[coin].iloc[i+1]
        if np.isfinite(p0) and p0 != 0 and np.isfinite(p1):
            coin_return = (p1 - p0) / p0
            long_return += long_weights[coin] * coin_return

    for coin in short_weights.index:
        p0 = price[coin].iloc[i]
        p1 = price[coin].iloc[i+1]
        if np.isfinite(p0) and p0 != 0 and np.isfinite(p1):
            coin_return = (p1 - p0) / p0
            short_return += short_weights[coin] * coin_return  # short_weights are already negative

    # Portfolio return: long + short - fees (short_return already negative)
    portfolio_return = long_return + short_return - 0.0005  # 5bps fees
    equity.append(equity[-1] * (1 + portfolio_return))

# %%
plt.plot(price.index[:len(equity)], equity)
plt.xlabel("Date")
plt.ylabel("Equity")
plt.title("Strategy Equity Curve")
plt.xticks(rotation=45)
plt.show()

# %%
# Example: align equity with df index
equity_series = pd.Series(equity, index=price.index[:len(equity)])

# BTC cumulative return
btc_cumret = (1 + price["BTCUSDT"].pct_change().fillna(0)).cumprod()

plt.plot(equity_series, label="Strategy Equity")
plt.plot(btc_cumret, label="BTC Cumulative Return")

plt.legend()
plt.show()

# %%
# Diagnostic: compare mean-variance weights vs score/vol heuristic for the next N valid signal days
from collections import defaultdict

def compute_mv_weights_for_day(i, mv_lookback=60, reg=1e-5, lambda_param=1.0):
    current_volumes = rolling_volume_matrix.iloc[i].dropna()
    if len(current_volumes) == 0:
        return None
    top_volume_tickers = current_volumes.nlargest(n_universe).index
    row = rets.iloc[i]
    filtered_returns = row[top_volume_tickers].dropna()
    if len(filtered_returns) == 0:
        return None

    # estimate mu/Sigma
    start_idx = max(0, i - mv_lookback + 1)
    returns_df = price[top_volume_tickers].pct_change().shift(1).iloc[start_idx:i+1].dropna(how='all')
    if returns_df.shape[0] < 10:
        return None
    mu = returns_df.mean()
    Sigma = returns_df.cov().values + reg * np.eye(len(returns_df.columns))
    try:
        raw_w = np.linalg.solve(lambda_param * Sigma, mu.values)
    except Exception:
        return None
    raw_w_series = pd.Series(raw_w, index=mu.index)
    longs_raw = raw_w_series[raw_w_series > 0]
    shorts_raw = raw_w_series[raw_w_series < 0]
    if len(longs_raw) == 0 or len(shorts_raw) == 0:
        return None
    long_w = longs_raw / longs_raw.sum() * 0.5
    short_w = (-shorts_raw) / (-shorts_raw).sum() * 0.5
    return long_w, short_w


def compute_scorevol_weights_for_day(i):
    current_volumes = rolling_volume_matrix.iloc[i].dropna()
    if len(current_volumes) == 0:
        return None
    top_volume_tickers = current_volumes.nlargest(n_universe).index
    row = rets.iloc[i]
    filtered_returns = row[top_volume_tickers].dropna()
    if len(filtered_returns) == 0:
        return None
    long_coins = filtered_returns.nlargest(k).index
    short_coins = filtered_returns.nsmallest(k).index
    long_vols = volatility.iloc[i][long_coins]
    short_vols = volatility.iloc[i][short_coins]
    long_scores = filtered_returns.reindex(long_coins)
    short_scores = filtered_returns.reindex(short_coins)
    long_ratio = (long_scores / long_vols).replace([np.inf, -np.inf], np.nan).dropna()
    short_ratio = ((-short_scores) / short_vols).replace([np.inf, -np.inf], np.nan).dropna()
    if len(long_ratio) == 0 or len(short_ratio) == 0:
        return None
    long_w = long_ratio / long_ratio.sum() * 0.5
    short_w = short_ratio / short_ratio.sum() * 0.5
    return long_w, short_w

# Run diagnostics for next N valid signal days
N = 10
printed = 0
mv_perf = []
sv_perf = []

diagnostics = []
for i in range(n, len(price)-1):
    mv = compute_mv_weights_for_day(i)
    sv = compute_scorevol_weights_for_day(i)
    if mv is None and sv is None:
        continue
    diag = {'date': price.index[i].date()}
    if mv is not None:
        long_mv, short_mv = mv
        diag['mv_long_sum'] = long_mv.sum()
        diag['mv_short_sum'] = short_mv.sum()
        diag['mv_long'] = long_mv.to_dict()
        diag['mv_short'] = short_mv.to_dict()
        # compute next-day portfolio return for MV
        lr = sum((price.loc[price.index[i+1], c] - price.loc[price.index[i], c]) / price.loc[price.index[i], c] * w for c, w in long_mv.items() if c in price.columns)
        sr = sum((price.loc[price.index[i+1], c] - price.loc[price.index[i], c]) / price.loc[price.index[i], c] * w for c, w in short_mv.items() if c in price.columns)
        mv_ret = lr - sr - 0.0005
        mv_perf.append(mv_ret)
        diag['mv_ret'] = mv_ret
    if sv is not None:
        long_sv, short_sv = sv
        diag['sv_long_sum'] = long_sv.sum()
        diag['sv_short_sum'] = short_sv.sum()
        diag['sv_long'] = long_sv.to_dict()
        diag['sv_short'] = short_sv.to_dict()
        lr = sum((price.loc[price.index[i+1], c] - price.loc[price.index[i], c]) / price.loc[price.index[i], c] * w for c, w in long_sv.items() if c in price.columns)
        sr = sum((price.loc[price.index[i+1], c] - price.loc[price.index[i], c]) / price.loc[price.index[i], c] * w for c, w in short_sv.items() if c in price.columns)
        sv_ret = lr - sr - 0.0005
        sv_perf.append(sv_ret)
        diag['sv_ret'] = sv_ret

    diagnostics.append(diag)
    printed += 1
    if printed >= N:
        break

# Print diagnostics
for d in diagnostics:
    print('\nDate:', d['date'])
    if 'mv_long_sum' in d:
        print(' MV long sum=', d['mv_long_sum'], ' MV short sum=', d['mv_short_sum'], ' MV ret=', d.get('mv_ret'))
        print('  MV longs:', d['mv_long'])
        print('  MV shorts:', d['mv_short'])
    if 'sv_long_sum' in d:
        print(' SV long sum=', d['sv_long_sum'], ' SV short sum=', d['sv_short_sum'], ' SV ret=', d.get('sv_ret'))
        print('  SV longs:', d['sv_long'])
        print('  SV shorts:', d['sv_short'])

# Small performance summary
if len(mv_perf) > 0:
    print('\nMV avg return over sample:', np.mean(mv_perf), ' std:', np.std(mv_perf))
if len(sv_perf) > 0:
    print('SV avg return over sample:', np.mean(sv_perf), ' std:', np.std(sv_perf))

print('\nDiagnostics complete')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_24720\2828614265.py:16: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns_df = price[top_volume_tickers].pct_change().shift(1).iloc[start_idx:i+1].dropna(how='all')
# C:\Users\USER\AppData\Local\Temp\ipykernel_24720\2828614265.py:16: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns_df = price[top_volume_tickers].pct_change().shift(1).iloc[start_idx:i+1].dropna(how='all')
# C:\Users\USER\AppData\Local\Temp\ipykernel_24720\2828614265.py:16: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns_df = price[top_volume_tickers].pct_change().shift(1).iloc[start_idx:i+1].dropna(how='all')
# C:\Users\USER\AppData\Local\Temp\ipykernel_24720\2828614265.py:16: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns_df = price[top_volume_tickers].pct_change().shift(1).iloc[start_idx:i+1].dropna(how='all')
# C:\Users\USER\AppData\Local\Temp\ipykernel_24720\2828614265.py:16: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns_df = price[top_volume_tickers].pct_change().shift(1).iloc[start_idx:i+1].dropna(how='all')
# C:\Users\USER\AppData\Local\Temp\ipykernel_24720\2828614265.py:16: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns_df = price[top_volume_tickers].pct_change().shift(1).iloc[start_idx:i+1].dropna(how='all')
# C:\Users\USER\AppData\Local\Temp\ipykernel_24720\2828614265.py:16: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns_df = price[top_volume_tickers].pct_change().shift(1).iloc[start_idx:i+1].dropna(how='all')
# C:\Users\USER\AppData\Local\Temp\ipykernel_24720\2828614265.py:16: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns_df = price[top_volume_tickers].pct_change().shift(1).iloc[start_idx:i+1].dropna(how='all')
# C:\Users\USER\AppData\Local\Temp\ipykernel_24720\2828614265.py:16: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns_df = price[top_volume_tickers].pct_change().shift(1).iloc[start_idx:i+1].dropna(how='all')
# Date: 2021-01-16
#  MV long sum= 0.49999999999999994  MV short sum= 0.5  MV ret= -0.023551489652584218
#   MV longs: {'DOGEUSDT': 0.0029936201291837707, 'IOSTUSDT': 0.07151580226351145, 'XRPUSDT': 0.020849466965091004, 'RSRUSDT': 0.0127420681869555, 'XLMUSDT': 0.06205004516585709, 'LRCUSDT': 0.029891447625466652, 'FLMUSDT': 0.034692150307796356, 'SKLUSDT': 0.01211727769461454, 'ALPHAUSDT': 0.03266245675392962, 'IOTAUSDT': 0.008763198235829758, 'DOTUSDT': 0.02678803777004494, 'SUSHIUSDT':